# %%
# Clean any old copy and clone YOUR repo
# !rm -rf /content/nanogpt-vision
# !git clone https://github.com/mdeepak08/nanogpt-vision.git /content/nanogpt-vision

# Go into the project
# %cd /content/nanogpt-vision

# Install dependencies (quietly)
# !pip install -q torch torchvision torchaudio numpy transformers datasets tiktoken wandb tqdm

# Sanity check: make sure A100 / CUDA is visible
import torch
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
# !nvidia-smi
# Out:
# Cloning into '/content/nanogpt-vision'...
# remote: Enumerating objects: 42, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 42 (delta 3), reused 42 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (42/42), 435.63 KiB | 48.40 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# /content/nanogpt-vision
# Torch version: 2.9.0+cu126
# CUDA available: True
# Sun Dec 14 14:14:48 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# ...

# %%
# Baseline vision transformer run with your current main.py
# %cd /content/nanogpt-vision
# !python main.py
# Out:
# /content/nanogpt-vision
# Using device: cuda
# 100% 9.91M/9.91M [00:01<00:00, 5.57MB/s]
# 100% 28.9k/28.9k [00:00<00:00, 134kB/s]
# 100% 1.65M/1.65M [00:01<00:00, 1.25MB/s]
# 100% 4.54k/4.54k [00:00<00:00, 18.5MB/s]
# 100% 26.4M/26.4M [00:02<00:00, 10.5MB/s]
# 100% 29.5k/29.5k [00:00<00:00, 192kB/s]
# 100% 4.42M/4.42M [00:01<00:00, 3.61MB/s]
# 100% 5.15k/5.15k [00:00<00:00, 37.0MB/s]
# Training samples: 120000
# Test samples: 20000
# Number of classes: 20
# Created Vision Transformer with 1,870,100 parameters
#
# Starting training...
#
# Epoch 1/5
# Training: 100% 938/938 [00:18<00:00, 49.54it/s, loss=0.575, acc=60.03%]
# Evaluating: 100% 157/157 [00:00<00:00, 168.50it/s]
#   Train loss: 1.1256, Train accuracy: 60.03%
#   Test loss: 0.5238, Test accuracy: 81.83%
#   Learning rate: 0.000905
#   Saved new best model with accuracy: 81.83%
#
# Epoch 2/5
# Training: 100% 938/938 [00:17<00:00, 52.83it/s, loss=0.166, acc=85.21%]
# Evaluating: 100% 157/157 [00:00<00:00, 175.55it/s]
# ...

# %%
# %cd /content/nanogpt-vision

# Start from a clean copy each time
# !cp main.py main_exp1.py

path = "main_exp1.py"
text = open(path).read()

# Longer training + slightly bigger model
text = text.replace("NUM_EPOCHS = 5", "NUM_EPOCHS = 10")
text = text.replace("EMBED_SIZE = 160", "EMBED_SIZE = 192")
text = text.replace("NUM_HEADS = 5", "NUM_HEADS = 6")  # 192 / 6 = 32 (OK)

open(path, "w").write(text)
print("Modified hyperparameters in main_exp1.py")

# !python main_exp1.py
# Out:
# /content/nanogpt-vision
# Modified hyperparameters in main_exp1.py
# Using device: cuda
# Training samples: 120000
# Test samples: 20000
# Number of classes: 20
# Created Vision Transformer with 2,686,484 parameters
#
# Starting training...
#
# Epoch 1/10
# Training: 100% 938/938 [00:17<00:00, 52.20it/s, loss=0.458, acc=64.01%]
# Evaluating: 100% 157/157 [00:00<00:00, 161.58it/s]
#   Train loss: 1.0134, Train accuracy: 64.01%
#   Test loss: 0.4512, Test accuracy: 84.24%
#   Learning rate: 0.000976
#   Saved new best model with accuracy: 84.24%
#
# Epoch 2/10
# Training: 100% 938/938 [00:17<00:00, 53.61it/s, loss=0.423, acc=86.40%]
# Evaluating: 100% 157/157 [00:01<00:00, 156.34it/s]
#   Train loss: 0.3922, Train accuracy: 86.40%
#   Test loss: 0.2983, Test accuracy: 89.52%
#   Learning rate: 0.000905
#   Saved new best model with accuracy: 89.52%
#
# Epoch 3/10
# Training: 100% 938/938 [00:17<00:00, 54.12it/s, loss=0.431, acc=89.29%]
# ...
